# %% [markdown]
# # Solving Stokes, in parallel

# %% [markdown]
# Starting an MPI-cluster on the local machine:

# %%
from ipyparallel import Cluster
c = await Cluster(engines="mpi").start_and_connect(n=4, activate=True)
# Out:
# Starting 4 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/ipyparallel/util.py:217: RuntimeWarning: IPython could not determine IPs for JS-M4.local: [Errno 8] nodename nor servname provided, or not known
#   warnings.warn(
#   0%|          | 0/4 [00:00<?, ?engine/s]

# %% [markdown]
# Generate and distribute mesh, refine in parallel:

# %%
# %%px
# from ngsolve import *
# from netgen.occ import *
# from ngsolve.krylovspace import BramblePasciakCG
# from mpi4py.MPI import COMM_WORLD as comm
#
# box = Box((0,0,0), (2,0.41,0.41))
# box.faces.name="wall"
# box.faces.Min(X).name="inlet"
# box.faces.Max(X).name="outlet"
# cyl = Cylinder((0.2,0,0.2), Y, h=0.41,r=0.05)
# cyl.faces.name="cyl"
# shape = box-cyl
# ngmesh = OCCGeometry(shape).GenerateMesh(maxh=0.05, comm=comm)
#
# for r in range(1): ngmesh.Refine()
# mesh = Mesh(ngmesh)
# print (mesh.GetNE(VOL))
# Out:
# [stdout:3] 36792
# [stdout:2] 36880
# [stdout:1] 35600
# [stdout:0] 0

# %% [markdown]
# Using parallel preconditioners from PETSc:
#
# (thanks a lot for support from S. Zampini and U. Zerbinat)

# %%
# %%px
# import ngsolve.ngs2petsc as n2p
# import petsc4py.PETSc as psc

# %% [markdown]
# A stabilized $p=1$ method for Stokes:
#
# $$
# K = \left( \begin{array}{cc}
#   A & B^T \\
#   B & -C
#    \end{array} \right)
# \qquad
# A = \left( \begin{array}{ccc}
#   A_1 & \cdot & \cdot \\
#   \cdot & A_1 & \cdot  \\
#   \cdot & \cdot & A_1  \\
#    \end{array} \right)
# $$

# %%
# %%px
# V = VectorH1(mesh, order=1, dirichlet="wall|inlet|cyl")
# V1 = H1(mesh, order=1, dirichlet="wall|inlet|cyl")
# Q = H1(mesh, order=1)
# printonce ("ndof = ", V.ndofglobal,'+',Q.ndofglobal,'=',
#         V.ndofglobal+Q.ndofglobal)
#
# u,v = V.TnT()
# u1,v1 = V1.TnT()
# p,q = Q.TnT()
#
# h = specialcf.mesh_size
#
# bfa1 = BilinearForm(InnerProduct(grad(u1),grad(v1))*dx)
# bfb = BilinearForm(div(u)*q*dx).Assemble()
# bfc = BilinearForm(h*h*grad(p)*grad(q)*dx).Assemble()
#
# prea1 = Preconditioner(bfa1, "gamg") # AMG precond from PETSc
# bfa1.Assemble()
#
# # make block-diagonal A matrix:
# mata = sum( [Ri.T@bfa1.mat@Ri for Ri in V.restrictions] )
# prea = sum( [Ei@prea1@Ei.T for Ei in V.embeddings])
#
# bfschur = BilinearForm(p*q*dx, diagonal=True).Assemble()
# preschur = bfschur.mat.Inverse()
# Out:
# [stdout:0] ndof =  66369 + 22123 = 88492

# %%
# %%px
# gfu = GridFunction(V)
# gfp = GridFunction(Q)
#
# uin = (1.5*4*y*(0.41-y)/(0.41*0.41)*z*(0.41-z)/0.41**2,0, 0)
#
# gfu.Set(uin, definedon=mesh.Boundaries("inlet"))
#
# resf = (-mata * gfu.vec).Evaluate()
# resg = (-bfb.mat * gfu.vec).Evaluate()
#
# sol = BramblePasciakCG (A=mata, B=bfb.mat, C=bfc.mat, f=resf, g=resg, \
#                 preA=prea, preS=preschur, maxit=500,
#                 printrates='\r' if comm.rank==0 else False)
#
# gfu.vec.data += sol[0]
# gfp.vec.data += sol[1]
# Out:
# [stdout:0] lammin/lammax =  0.5084872498550447 / 0.9982816728290529
# Iteration 154 err= 6.920078257638982e-09

# %%
gfu = c[:]["gfu"]

# %%
from ngsolve import *
from ngsolve.webgui import Draw
ea = { "euler_angles" : (-77, 6, 47) }
clipping = { "clipping" : {"y":1, "z":0, "function" : True } }
Draw (Norm(gfu[0]), gfu[0].space.mesh, **ea, **clipping, order=1)
Draw (Norm(gfu[2]), gfu[2].space.mesh, **ea, **clipping, order=1);
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {'camera': {'euler_angles': (-…
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {'camera': {'euler_angles': (-…

# %%
gfp = c[:]["gfp"]
Draw (gfp[0], order=1, **ea, **clipping);
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {'camera': {'euler_angles': (-…

# %%
c.shutdown(hub=True)
# Out:
# Output for ipengine-1764059878-cx7g-1764059879-57302:
# 2025-11-25 08:38:00.120 [IPEngine.1.1] Connecting shell to tcp://127.0.0.1:56753
# 2025-11-25 08:38:00.120 [IPEngine.1.1] Connecting shell to tcp://127.0.0.1:56758
# 2025-11-25 08:38:00.120 [IPEngine.1.1] Starting nanny
# 2025-11-25 08:38:00.121 [IPEngine.3.3] Shell_addrs: ['tcp://127.0.0.1:56752', 'tcp://127.0.0.1:56753', 'tcp://127.0.0.1:56758']
# 2025-11-25 08:38:00.121 [IPEngine.3.3] Connecting shell to tcp://127.0.0.1:56752
# 2025-11-25 08:38:00.121 [IPEngine.3.3] Connecting shell to tcp://127.0.0.1:56753
# 2025-11-25 08:38:00.121 [IPEngine.3.3] Connecting shell to tcp://127.0.0.1:56758
# 2025-11-25 08:38:00.121 [IPEngine.3.3] Starting nanny
# 2025-11-25 08:38:00.121 [IPEngine.2.2] Shell_addrs: ['tcp://127.0.0.1:56752', 'tcp://127.0.0.1:56753', 'tcp://127.0.0.1:56757']
# 2025-11-25 08:38:00.121 [IPEngine.2.2] Connecting shell to tcp://127.0.0.1:56752
# 2025-11-25 08:38:00.121 [IPEngine.2.2] Connecting shell to tcp://127.0.0.1:56753
# 2025-11-25 08:38:00.121 [IPEngine.2.2] Connecting shell to tcp://127.0.0.1:56757
# 2025-11-25 08:38:00.122 [IPEngine.2.2] Starting nanny
# 2025-11-25 08:38:00.122 [IPEngine.0.0] Shell_addrs: ['tcp://127.0.0.1:56752', 'tcp://127.0.0.1:56753', 'tcp://127.0.0.1:56757']
# 2025-11-25 08:38:00.122 [IPEngine.0.0] Connecting shell to tcp://127.0.0.1:56752
# 2025-11-25 08:38:00.122 [IPEngine.0.0] Connecting shell to tcp://127.0.0.1:56753
# 2025-11-25 08:38:00.122 [IPEngine.0.0] Connecting shell to tcp://127.0.0.1:56757
# 2025-11-25 08:38:00.122 [IPEngine.0.0] Starting nanny
# 2025-11-25 08:38:00.354 [KernelNanny.3] Starting kernel nanny for engine 3, pid=57323, nanny pid=57325
# 2025-11-25 08:38:00.354 [KernelNanny.2] Starting kernel nanny for engine 2, pid=57321, nanny pid=57326
# 2025-11-25 08:38:00.354 [KernelNanny.1] Starting kernel nanny for engine 1, pid=57319, nanny pid=57324
# 2025-11-25 08:38:00.354 [KernelNanny.0] Starting kernel nanny for engine 0, pid=57318, nanny pid=57327
# 2025-11-25 08:38:00.354 [KernelNanny.3] Nanny watching parent pid 57323.
# 2025-11-25 08:38:00.354 [KernelNanny.1] Nanny watching parent pid 57319.
# 2025-11-25 08:38:00.354 [KernelNanny.2] Nanny watching parent pid 57321.
# 2025-11-25 08:38:00.354 [KernelNanny.0] Nanny watching parent pid 57318.
# 2025-11-25 08:38:00.403 [IPEngine.1.1] Loading IPython extension: storemagic
# 2025-11-25 08:38:00.403 [IPEngine.0.0] Loading IPython extension: storemagic
# 2025-11-25 08:38:00.403 [IPEngine.3.3] Loading IPython extension: storemagic
# 2025-11-25 08:38:00.403 [IPEngine.2.2] Loading IPython extension: storemagic
# 2025-11-25 08:38:00.403 [IPEngine.1.1] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2025-11-25 08:38:00.403 [IPEngine.0.0] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2025-11-25 08:38:00.403 [IPEngine.3.3] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2025-11-25 08:38:00.403 [IPEngine.2.2] Running code in user namespace:
# from mpi4py import MPI
# mpi_rank = MPI.COMM_WORLD.Get_rank()
# mpi_size = MPI.COMM_WORLD.Get_size()
#
# 2025-11-25 08:38:00.404 [IPEngine.2.2] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-11-25 08:38:00.404 [IPEngine.0.0] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-11-25 08:38:00.404 [IPEngine.3.3] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-11-25 08:38:00.404 [IPEngine.1.1] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-11-25 08:38:00.406 [IPEngine.0.0] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-11-25 08:38:00.406 [IPEngine.2.2] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-11-25 08:38:00.406 [IPEngine.1.1] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-11-25 08:38:00.406 [IPEngine.3.3] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-11-25 08:38:00.406 [IPEngine.0.0] Completed registration with id 0
# 2025-11-25 08:38:00.406 [IPEngine.2.2] Completed registration with id 2
# 2025-11-25 08:38:00.406 [IPEngine.1.1] Completed registration with id 1
# 2025-11-25 08:38:00.406 [IPEngine.3.3] Completed registration with id 3
# 2025-11-25 08:38:07.658 [IPEngine.0.0] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_1
# 2025-11-25 08:38:07.663 [IPEngine.1.1] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_2
# 2025-11-25 08:38:07.663 [IPEngine.2.2] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_3
# 2025-11-25 08:38:07.664 [IPEngine.3.3] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_4
# 2025-11-25 08:38:09.116 [IPEngine.0.0] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_5
# 2025-11-25 08:38:09.118 [IPEngine.1.1] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_6
# 2025-11-25 08:38:09.119 [IPEngine.2.2] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_7
# 2025-11-25 08:38:09.120 [IPEngine.3.3] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_8
# 2025-11-25 08:38:09.943 [IPEngine.0.0] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_9
# 2025-11-25 08:38:09.944 [IPEngine.1.1] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_10
# 2025-11-25 08:38:09.946 [IPEngine.2.2] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_11
# 2025-11-25 08:38:09.947 [IPEngine.3.3] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_12
# 2025-11-25 08:38:10.449 [IPEngine.0.0] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_13
# 2025-11-25 08:38:10.451 [IPEngine.1.1] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_14
# 2025-11-25 08:38:10.451 [IPEngine.2.2] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_15
# 2025-11-25 08:38:10.452 [IPEngine.3.3] Handling execute_request: f5057180-884557221ae49f574370d8a7_57302_16
# 2025-11-25 08:38:11.461 [IPEngine.0.0] Handling apply_request: f5057180-884557221ae49f574370d8a7_57302_17
# 2025-11-25 08:38:11.461 [IPEngine.1.1] Handling apply_request: f5057180-884557221ae49f574370d8a7_57302_18
# 2025-11-25 08:38:11.461 [IPEngine.2.2] Handling apply_request: f5057180-884557221ae49f574370d8a7_57302_19
# 2025-11-25 08:38:11.461 [IPEngine.3.3] Handling apply_request: f5057180-884557221ae49f574370d8a7_57302_20
# 2025-11-25 08:38:12.572 [IPEngine.0.0] Handling apply_request: f5057180-884557221ae49f574370d8a7_57302_21
# 2025-11-25 08:38:12.576 [IPEngine.1.1] Handling apply_request: f5057180-884557221ae49f574370d8a7_57302_22
# 2025-11-25 08:38:12.577 [IPEngine.2.2] Handling apply_request: f5057180-884557221ae49f574370d8a7_57302_23
# 2025-11-25 08:38:12.578 [IPEngine.3.3] Handling apply_request: f5057180-884557221ae49f574370d8a7_57302_24
# 2025-11-25 08:38:16.468 [KernelNanny.3] Pipe closed, parent 57323 has status: None
# 2025-11-25 08:38:16.468 [KernelNanny.3] Notifying Hub that our parent has shut down
# 2025-11-25 08:38:16.468 [KernelNanny.1] Pipe closed, parent 57319 has status: zombie
# 2025-11-25 08:38:16.468 [KernelNanny.1] Notifying Hub that our parent has shut down
# 2025-11-25 08:38:16.469 [KernelNanny.2] Pipe closed, parent 57321 has status: zombie
# 2025-11-25 08:38:16.469 [KernelNanny.2] Notifying Hub that our parent has shut down
# 2025-11-25 08:38:16.469 [KernelNanny.0] Pipe closed, parent 57318 has status: zombie
# 2025-11-25 08:38:16.469 [KernelNanny.0] Notifying Hub that our parent has shut down
# --------------------------------------------------------------------------
# prterun detected that one or more processes exited with non-zero status,
# thus causing the job to be terminated. The first process to do so was:
#
#    Process name: [prterun-JS-M4-57316@1,3] Exit code:    1
# --------------------------------------------------------------------------
#
# engine set stopped 1764059879: {'exit_code': 1, 'pid': 57316, 'identifier': 'ipengine-1764059878-cx7g-1764059879-57302'}
# Controller stopped: {'exit_code': 0, 'pid': 57306, 'identifier': 'ipcontroller-1764059878-cx7g-57302'}
